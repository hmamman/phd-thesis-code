# %%
import pandas as pd
import numpy as np
import glob

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairCES', 'FairPES', 'S-ES']
metrics = {'#IDI': '#IDI (Thousand)', 'GSR': 'GSR (%)'}

# Values from the image
values = {
    '#IDI': [i/1000 for i in [402914, 420598, 291028]],
    'GSR': [66.07, 67.75, 43.00]
}

# Colors similar to the original code
colors = ['blue', 'green', 'orange']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 2, figsize=(6, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes[i].bar(methods, values[metric], color=colors)
    axes[i].set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes[i].grid(False, axis='y')
    axes[i].grid(False, axis='x')
    axes[i].spines['top'].set_visible(False)
    axes[i].spines['right'].set_visible(False)
    axes[i].tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
methods = ['FairPHS', 'FairESTEO', 'AFT', 'FairPES']
#IDI
# Raw values from table (converted from comma format)
data = np.array([
    [884111, 347649, 505741, 243647],   # FairPHS
    [827978, 326931, 392486, 208031],   # FairEST EO
    [797153, 590070, 331933, 247195],   # AFT
    [812997, 302954, 372898, 189965],   # FairPES
]) / 1000  # Convert to thousands

[495287,438857,491588,419704]
# GSR
data = np.array([
    [89.8, 79.34, 51.96, 71.39],   # FairPHS
    [88.91, 81.6, 43.06, 65.1],    # FairESEO
    [79.21, 62.03, 34.22, 34.11],  # AFT
    [88.74, 78.72, 41.6, 61.86],   # FairPES
])

[73.12,69.67,52.39,67.73]

#DGS
data = np.array([
    [105.28, 105.28, 519.16, 73.78],   # FairPHS
    [98.99, 98.99, 375.54, 62.99],     # FairESTEO
    [296.79, 296.79, 671.84, 89.19],   # AFT
    [91.73, 91.73, 356.05, 57.51],     # FairPES
])
[200.88,159.13,338.65,149.26]

#FAIRSIFT

#MIC
data = np.array([
    [5000, 5000, 5000, 5000],   # FairSIFT
    [3068865, 1203660, 3675673, 1092760],   # FairPHS
    [731128, 767315, 1045312, 1092760],   # AFT
])
[5000,2260240,840771]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Define models and methods
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairSIFT', 'FairPHS', 'AFT']

# Raw values from table (converted from comma format)
data = np.array([
    [89.92, 79.13, 53.55, 71.64],  # FairSIFT
    [89.80, 79.34, 51.96, 71.39],  # FairPHS
    [79.21, 62.03, 34.22, 34.11],  # AFT
])


# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('GSR %', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()


# Define the data from the image
methods = ['FairSIFT', 'FairPHS', 'AFT']
metrics = {'GSR': 'GSR %'}

# Values from the image
values = {
    'GSR':[73.56, 73.12, 52.39],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(5, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Define models and methods
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairSIFT', 'FairPHS', 'AFT']

# Raw values from table (converted from comma format)
data = np.array([
    [20409.31, 11633.89, 1121.72, 11946.77],  # FairSIFT
    [3207.06, 105.28, 519.16, 73.78],         # FairPHS
    [7725.93, 296.79, 671.84, 89.19],         # AFT
])/1000




# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

# ax.set_yscale('log')
ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('DGS (Thousand)', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairSIFT', 'FairPHS', 'AFT']
metrics = {'DGS': 'DGS (Thousand)'}

# Values from the image
values = {
    'DGS':np.array([11277.92, 976.32, 2195.94])/1000,
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(3, 2))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    # axes.set_yscale('log')
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Define models and methods
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairSIFT', 'FairPHS', 'AFT']

# Raw values from table (converted from comma format)
data = np.array([
    [177.07, 154.63, 104.28, 140.31],  # FairSIFT
    [0.29, 0.29, 0.14, 0.22],          # FairPHS
    [1.09, 0.77, 0.32, 0.30],          # AFT
])



# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

# ax.set_yscale('log')
ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('IGR', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairSIFT', 'FairPHS', 'AFT']
metrics = {'IGR': 'IGR'}

# Values from the image
values = {
    'IGR':[144.07,0.24,0.62],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(3, 2))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    # axes.set_yscale('log')
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairPHS', 'FairESTEO', 'AFT', 'FairPES']
metrics = {'GSR': 'GSR %'}

# Values from the image
values = {
    'GSR':[73.12,69.67,52.39,67.73],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(5, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Define models and methods
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairPHS', 'FairESTEO', 'AFT', 'FairPES']

# Raw values from table (converted from comma format)
data = np.array([
    [89.8, 79.34, 51.96, 71.39],   # FairPHS
    [88.91, 81.6, 43.06, 65.1],    # FairESEO
    [79.21, 62.03, 34.22, 34.11],  # AFT
    [88.74, 78.72, 41.6, 61.86],   # FairPES
])


# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('GSR %', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Define models and methods
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairPHS', 'FairESTEO', 'AFT', 'FairPES']

# Raw values from table (converted from comma format)
data = np.array([
    [105.28, 105.28, 519.16, 73.78],   # FairPHS
    [98.99, 98.99, 375.54, 62.99],     # FairESTEO
    [296.79, 296.79, 671.84, 89.19],   # AFT
    [91.73, 91.73, 356.05, 57.51],     # FairPES
])


# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('DGS', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairPHS', 'FairESTEO', 'AFT', 'FairPES']
metrics = {'DGS': 'DGS'}

# Values from the image
values = {
    'DGS':[200.88,159.13,338.65,149.26],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(5, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Hi‑res output
plt.rcParams['figure.dpi']  = 300
plt.rcParams['savefig.dpi'] = 300

# ─── Data ────────────────────────────────────────────────────────────
methods = ['FairSIFT', 'FairPHS', 'AFT']

mic = np.array([5_000, 2_260_240, 840_771])
ts  = np.array([297.90, 2_014.92, 1_809.88])          # average TS (your earlier table)
idi = np.array([720_353, 495_287, 491_588]) / 1000.0  # thousands for nicer scale

colors = ['blue', 'orange', 'green']

# ─── Figure with two horizontally stacked axes ───────────────────────
fig, axs = plt.subplots(1, 2, figsize=(8.2, 2.8), sharey=True)

# ─ Left panel: MIC vs #IDI ───────────────────────────────────────────
axs[0].scatter(mic, idi, color=colors, s=60)

for method, x, y in zip(methods, mic, idi):
    axs[0].annotate(method, (x, y), xytext=(0, 8), textcoords='offset points',
                    ha='center', fontsize=8)

axs[0].set_xscale('log')
axs[0].set_xlabel('Inf. (log scale)', fontsize=12)
axs[0].set_ylabel('#IDI (Thousand)', fontsize=12)
axs[0].grid(False)
axs[0].margins(x=0.15, y=0.15)

# ─ Right panel: TS vs #IDI ───────────────────────────────────────────
axs[1].scatter(ts, idi, color=colors, s=60)

for method, x, y in zip(methods, ts, idi):
    axs[1].annotate(method, (x, y), xytext=(0, 8), textcoords='offset points',
                    ha='center', fontsize=8)

# log‑scale optional—comment out next line if you prefer linear
# axs[1].set_xscale('log')
axs[1].set_xlabel('TS', fontsize=11)
axs[1].set_ylabel('#IDI (Thousand)', fontsize=12)
axs[1].grid(False)
axs[1].margins(x=0.15, y=0.15)

# ─ Final layout tweaks ───────────────────────────────────────────────
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairCES', 'ExpGA', 'AEQUITAS', 'SG', 'VBT-X']
metrics = {'#IDI': '#IDI (Thousand)'}

# Values from the image
values = {
    '#IDI': [67.73, 55.70, 14.82,38.56,23.52],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red', 'black']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(5, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Data from image (in thousands)
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairPES', 'ExpGA', 'AEQUITAS', 'SG', 'VBT-X']

# Values per method per model (rows: methods, cols: models)
data = np.array([
    [812997, 302954, 372898, 189965],   # FairPES
    [447091, 100194, 149857,  27990],   # ExpGA
    [  2717,   2327,    932,    839],   # AEQUITAS
    [ 10208,   7462,    867,   5547],   # SG
    [ 18092,   5519,   1204,   1429],   # VBT-X
]) / 1000  # Convert to thousands

# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('#IDI (Thousand)', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairCES', 'ExpGA', 'AEQUITAS', 'SG', 'VBT-X']
metrics = {'#IDI': '#IDI (Thousand)'}

# Values from the image
values = {
    '#IDI': [67.73, 55.70, 14.82,38.56,23.52],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red', 'black']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(5, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Define models and methods
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairPES', 'ExpGA', 'AEQUITAS', 'SG', 'VBT-X']

# New values from the table (not the average row)
data = np.array([
    [88.74, 78.72, 41.60, 61.86],   # FairPES
    [79.50, 59.95, 33.59, 49.74],   # ExpGA
    [24.93, 18.38,  5.99,  9.98],   # AEQUITAS
    [51.61, 47.03, 17.83, 37.78],   # SG
    [56.66, 23.73,  6.07,  7.63],   # VBT-X
])

# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

# Draw bars
for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

# Customize axes
ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('GSR (%)', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairPES', 'ExpGA', 'AEQUITAS', 'SG', 'VBT-X']
metrics = {'GSR': 'GSR (%)'}

# Values from the image
values = {
    'GSR': [67.73, 55.70, 14.82, 38.56, 23.52],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red', 'black']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(5, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# Define models and methods
models = ['DT', 'RF', 'SVM', 'DNN']
methods = ['FairPES', 'ExpGA', 'AEQUITAS', 'SG', 'VBT-X']

# New values from the table (not the average row)
data = np.array([
    [3095.11, 91.73, 356.05, 57.51],   # FairPES
    [1236.36, 30.35, 81.38, 8.48],     # ExpGA
    [31.18, 0.89, 1.66, 0.19],         # AEQUITAS
    [3.09, 2.26, 0.26, 1.68],          # SG
    [5.48, 1.67, 0.36, 0.43],          # VBT-X
])

# Plotting
fig, ax = plt.subplots(figsize=(6, 3))

bar_width = 0.15
x = np.arange(len(models))

colors = ['blue', 'orange', 'green', 'red', 'black']

# Draw bars
for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[i], width=bar_width, label=methods[i], color=colors[i])

# Customize axes
ax.set_xticks(x + bar_width * 2)
ax.set_xticklabels(models, fontsize=12)
ax.set_ylabel('DGS', fontsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', which='major', labelsize=10)
ax.legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Increase plot resolution
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300


# Define the data from the image
methods = ['FairPES', 'ExpGA', 'AEQUITAS', 'SG', 'VBT-X']
metrics = {'DGS': 'DGS'}

# Values from the image
values = {
    'DGS': [900.10,339.14,8.48,1.82,1.99],
}

# Colors similar to the original code
colors = ['blue', 'orange', 'green', 'red', 'black']

# Create separate vertical bar charts for each metric, placed horizontally
fig, axes = plt.subplots(1, 1, figsize=(5, 2.5))

for i, metric in enumerate(metrics.keys()):
    axes.bar(methods, values[metric], color=colors)
    axes.set_ylabel(f'{metrics[metric]}', fontsize=12)
    # axes[i].set_title(f'Comparison of {metric}', fontsize=12)
    axes.grid(False, axis='y')
    axes.grid(False, axis='x')
    axes.spines['top'].set_visible(False)
    axes.spines['right'].set_visible(False)
    axes.tick_params(axis='both', which='major', labelsize=12)

# Add general title
# fig.suptitle('Comparison of the average effectiveness FairES variants against the baseline S-ES method across all datasets and models.', fontsize=12, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to fit title properly
plt.show()
